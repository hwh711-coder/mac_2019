# %% [markdown]
# ![qiita.com_Blueman81_items_72ca43681d16d44e21ad.png](attachment:b9daffba-74fe-41f0-b6d3-7139d5d040cb.png)

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## <span style="color: red; ">Color text<span/>
#
# ```
# <span style="color: red; ">
# ```
#
# ```
# <span/>
# ```

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>
#
# ![notepm.jp_help_how-to-markdown.png](attachment:5f79b851-33e0-4f4e-89b8-b4bc4fac4887.png)
